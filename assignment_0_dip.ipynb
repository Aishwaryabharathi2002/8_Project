# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishwaryabharathi2002/8_Project/blob/main/assignment_0_dip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
img_1=cv2.imread("/content/1.jpeg")
cv2_imshow(img_1)
img_2=cv2.imread("/content/2.jpeg")
cv2_imshow(img_2)
img_3=cv2.imread("/content/3.jpeg")
cv2_imshow(img_3)
img_4=cv2.imread("/content/4.jpeg")
cv2_imshow(img_4)
# Out:
# <PIL.Image.Image image mode=RGB size=279x181 at 0x7FA5E0D81410>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FA5E0D81C50>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FA5E0D8B890>
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FA5E0D6BA10>

# %%
from matplotlib import pyplot as plt
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax1.imshow(img_1)
ax2=fig.add_subplot(2,2,2)
ax2.imshow(img_2)
ax3=fig.add_subplot(2,2,3)
ax3.imshow(img_3)
ax4=fig.add_subplot(2,2,4)
ax4.imshow(img_4)

# %%
from matplotlib import pyplot as plt
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax1.imshow(img_1[:,:,::-1])
ax2=fig.add_subplot(2,2,2)
ax2.imshow(img_2[:,:,::-1])
ax3=fig.add_subplot(2,2,3)
ax3.imshow(img_3[:,:,::-1])
ax4=fig.add_subplot(2,2,4)
ax4.imshow(img_4[:,:,::-1])

# %%
img_gray = cv2.imread('4.jpeg', 0) # The zero tells OpenCV to read the image as grayscale
plt.figure(figsize = [10,10])
plt.imshow(img_gray,cmap='gray')
plt.axis('off')
plt.show()

# %%
img= cv2.imread("4.jpeg")

print("Rows, Columns, Channels", img.shape)
# Out:
# Rows, Columns, Channels (194, 259, 3)
